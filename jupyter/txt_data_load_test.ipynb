# %%
import urllib3
import json
import pandas as pd

# import os
# ## Python이 실행될 때 DJANGO_SETTINGS_MODULE이라는 환경 변수에 현재 프로젝트의 settings.py파일 경로를 등록합니다.
# os.environ.setdefault("DJANGO_SETTINGS_MODULE", "config.settings")
# ## 이제 장고를 가져와 장고 프로젝트를 사용할 수 있도록 환경을 만듭니다.
# import django
# django.setup()

# from rest_framework import status
# from rest_framework.decorators import api_view
# from rest_framework.response import Response

from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search

# from config import settings

# %%
# from pathlib import Path

# BASE_DIR = Path(__file__).resolve(strict=True).parent.parent

# data import
with open('../env/etc/data/ubic_product_user_number.txt') as f:
    data = f.read().strip()

data = json.loads(data)

# %%
pd.DataFrame(data)
# Out:
#                       _index _type   _id  _score                      _source
# 0   ubic_product_user_number  _doc  2921     1.0  {'userNumber': {'2921': 1}}
# 1   ubic_product_user_number  _doc   137     1.0   {'userNumber': {'137': 2}}
# 2   ubic_product_user_number  _doc    95     1.0    {'userNumber': {'95': 3}}
# 3   ubic_product_user_number  _doc   148     1.0   {'userNumber': {'148': 0}}
# 4   ubic_product_user_number  _doc   100     1.0   {'userNumber': {'100': 0}}
# 5   ubic_product_user_number  _doc    -1     1.0    {'userNumber': {'-1': 0}}
# 6   ubic_product_user_number  _doc    98     1.0    {'userNumber': {'98': 1}}
# 7   ubic_product_user_number  _doc    97     1.0    {'userNumber': {'97': 1}}
# 8   ubic_product_user_number  _doc    96     1.0    {'userNumber': {'96': 1}}
# 9   ubic_product_user_number  _doc    99     1.0    {'userNumber': {'99': 4}}
# 10  ubic_product_user_number  _doc   355     1.0   {'userNumber': {'355': 0}}
# 11  ubic_product_user_number  _doc    94     1.0    {'userNumber': {'94': 1}}
# 12  ubic_product_user_number  _doc  1188     1.0  {'userNumber': {'1188': 6}}
# 13  ubic_product_user_number  _doc  2911     1.0  {'userNumber': {'2911': 0}}
# 14  ubic_product_user_number  _doc   194     1.0   {'userNumber': {'194': 0}}
# 15  ubic_product_user_number  _doc   702     1.0   {'userNumber': {'702': 1}}
# 16  ubic_product_user_number  _doc  2910     1.0  {'userNumber': {'2910': 2}}
# 17  ubic_product_user_number  _doc   556     1.0   {'userNumber': {'556': 0}}
# 18  ubic_product_user_number  _doc   597     1.0   {'userNumber': {'597': 0}}
# 19  ubic_product_user_number  _doc   503     1.0   {'userNumber': {'503': 1}}
# 20  ubic_product_user_number  _doc   232     1.0   {'userNumber': {'232': 7}}
# 21  ubic_product_user_number  _doc   144     1.0   {'userNumber': {'144': 3}}
# 22  ubic_product_user_number  _doc   107     1.0   {'userNumber': {'107': 0}}
# 23  ubic_product_user_number  _doc   110     1.0   {'userNumber': {'110': 1}}
# 24  ubic_product_user_number  _doc   141     1.0   {'userNumber': {'141': 0}}
# 25  ubic_product_user_number  _doc   117     1.0   {'userNumber': {'117': 5}}
# 26  ubic_product_user_number  _doc   146     1.0   {'userNumber': {'146': 0}}
# 27  ubic_product_user_number  _doc   145     1.0   {'userNumber': {'145': 0}}
# 28  ubic_product_user_number  _doc   111     1.0   {'userNumber': {'111': 0}}
# 29  ubic_product_user_number  _doc  1171     1.0  {'userNumber': {'1171': 0}}
# 30  ubic_product_user_number  _doc   124     1.0  {'userNumber': {'124': 66}}
# 31  ubic_product_user_number  _doc   109     1.0   {'userNumber': {'109': 0}}
# 32  ubic_product_user_number  _doc   478     1.0   {'userNumber': {'478': 0}}
# 33  ubic_product_user_number  _doc   116     1.0   {'userNumber': {'116': 2}}
# 34  ubic_product_user_number  _doc   389     1.0   {'userNumber': {'389': 1}}
# 35  ubic_product_user_number  _doc  1168     1.0  {'userNumber': {'1168': 8}}
# 36  ubic_product_user_number  _doc   682     1.0  {'userNumber': {'682': 35}}
# 37  ubic_product_user_number  _doc   131     1.0  {'userNumber': {'131': 23}}
# 38  ubic_product_user_number  _doc   570     1.0   {'userNumber': {'570': 3}}
# 39  ubic_product_user_number  _doc   132     1.0   {'userNumber': {'132': 1}}
# 40  ubic_product_user_number  _doc   125     1.0   {'userNumber': {'125': 1}}
# 41  ubic_product_user_number  _doc   130     1.0  {'userNumber': {'130': 13}}
# 42  ubic_product_user_number  _doc   140     1.0   {'userNumber': {'140': 1}}
# 43  ubic_product_user_number  _doc   571     1.0   {'userNumber': {'571': 0}}
# 44  ubic_product_user_number  _doc   573     1.0   {'userNumber': {'573': 0}}
# 45  ubic_product_user_number  _doc   685     1.0   {'userNumber': {'685': 0}}
# 46  ubic_product_user_number  _doc   366     1.0   {'userNumber': {'366': 0}}
# 47  ubic_product_user_number  _doc   392     1.0   {'userNumber': {'392': 0}}
# 48  ubic_product_user_number  _doc  1104     1.0  {'userNumber': {'1104': 0}}
# 49  ubic_product_user_number  _doc   683     1.0   {'userNumber': {'683': 0}}
# 50  ubic_product_user_number  _doc  1065     1.0  {'userNumber': {'1065': 0}}
