# %%
import csv
import json
import collections

csvfile = open('product_id_list.txt', 'r')

fieldnames = ("product_id",)
reader = csv.DictReader(csvfile, fieldnames)


product_id_list = []
for row in reader:
    product_id_list.append(int(row['product_id']))
    
# return product_id_list

print(product_id_list)
# Out:
# [94, 126, 148, 176, 208, 224, 247, 268, 290, 321, 349, 371, 395, 423, 448, 470, 490, 512, 524, 542, 560, 592, 611, 628, 647, 664, 683, 710, 727, 743, 759, 778, 802, 818, 832, 855, 881, 910, 941, 967, 987, 1016, 1045, 1071, 1094, 1118, 1146, 1165, 1187, 1209, 1229, 1245, 1262, 1275, 1299, 1320, 1343, 1358, 1374, 1405, 1428, 1454, 1479, 1504, 1525, 1540, 1559, 1581, 1598, 1623, 1643, 1661, 1683, 1701, 1723, 1737, 1757, 1784, 1809, 1832, 1849, 1867, 1881, 1898, 1915, 1932, 1950, 1968, 1984, 2000, 2015, 2030, 2045, 2063, 2080, 2095, 2108, 2123, 2140, 2153, 2171, 2193, 2207, 2223, 2237, 2258, 2286, 2316, 2337, 2362, 2387, 2408, 2443, 2469, 2489, 2515, 2541, 2568, 2588, 2602, 2620, 2635, 2651, 2680, 2697, 2712, 2733, 2753, 2769, 2789, 2813, 2836, 2852, 2865, 2886, 2901, 2914, 2935, 2957, 2975, 3005, 3022, 3040, 3058, 3075, 3097, 3115, 3137, 3148, 3166, 3191, 3214, 3239, 3263, 3285, 3301, 3320, 3339, 3367, 3399, 3421, 3444, 3460, 3480, 3502, 3522, 3549, 3569, 3587, 3597, 3616, 3632, 3652, 3
# ...

# %%
type(product_id_list)
# Out:
# list
